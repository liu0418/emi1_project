# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
import statistics

# %%
bigDir=r'X:\Liu\for_brandon\EMI1_NEW\REP_1'

# %%
file=f'{bigDir}\\cell_data_A1_df.csv'
file1=f'{bigDir}\\cell_data_A3_df.csv'
file2=f'{bigDir}\\cell_data_A5_df.csv'

# %%
#data untreated group
#data1 palbo treated group
#data2 emi1+palbo treated

data=pd.read_csv(file)
data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data
# Out:
#        Unnamed: 0  label   area    centroid-0   centroid-1  orientation  \
# 0              25     45  340.0     27.541176  7519.105882     0.202087
# 1              27     47  655.0     31.523664  8071.366412     0.619441
# 2              28     48  561.0     30.932264  1050.964349     0.645813
# 3              29     49  734.0     29.674387  9246.904632    -1.517063
# 4              30     50  462.0     32.110390  1110.318182     0.355973
# ...           ...    ...    ...           ...          ...          ...
# 31180       31280  31329  120.0  11832.475000  1709.466667    -1.342774
# 31181       31281  31330   91.0  11830.879121  3923.571429    -1.556140
# 31182       31282  31331  172.0  11833.360465  1010.412791    -1.564047
# 31183       31283  31332   71.0  11831.957746  3582.901408    -1.554509
# 31184       31284  31333   96.0  11834.947917   271.385417    -1.522028
#
#        major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# 0              27.802093          15.617922      14    7512  ...
# 1              38.914217          21.480542      15    8058  ...
# 2              33.850641          21.468238      16    1038  ...
# 3              32.804421          28.602714      16    9232  ...
# 4              32.500817          18.101059      17    1101  ...
# ...                  ...                ...     ...     ...  ...
# 31180          14.040651          11.058888   11827    1703  ...
# 31181          13.833726           8.649746   11827    3917  ...
# 31182          22.136738          10.474620   11828    1000  ...
# 31183          15.327727           6.091146   11829    3576  ...
# 31184          18.215351           6.888215   11832     263  ...
#
#        01_EdU_nuc_median  nuc_mask  00_DNA_ring_median  00_EMI1_ring_median  \
# 0                  169.0       0.0               125.0                419.0
# 1                  322.0       0.0               132.0                425.0
# 2                  181.0       0.0               144.0                449.0
# 3                  171.0       0.0               138.0                421.0
# 4                  191.0       0.0               132.0                428.0
# ...                  ...       ...                 ...                  ...
# 31180              173.0       0.0               127.5                401.0
# 31181              183.0       0.0               126.0                403.0
# 31182              823.0       0.0               133.0                416.0
# 31183             1365.0       0.0                 0.0                  0.0
# 31184             1201.5       0.0               127.0                409.0
#
#        00_cycB1-YFP_ring_median  00_53BP1_ring_median  01_DNA_ring_median  \
# 0                         377.0                 129.0                71.0
# 1                         357.0                 132.0               123.0
# 2                         852.0                 134.0               134.0
# 3                         505.0                 140.0               127.0
# 4                         348.0                 132.0               141.0
# ...                         ...                   ...                 ...
# 31180                     312.5                 129.0               147.5
# 31181                     305.0                 129.0               190.0
# 31182                     330.0                 129.0               158.0
# 31183                       0.0                   0.0               200.5
# 31184                     319.0                 129.5               157.5
#
#        01_EdU_ring_median  ring_mask  well
# 0                    18.0        0.0    A1
# 1                   169.0        0.0    A1
# 2                   168.0        0.0    A1
# 3                   168.0        0.0    A1
# 4                   176.0        0.0    A1
# ...                   ...        ...   ...
# 31180               173.0        0.0    A1
# 31181               181.0        0.0    A1
# 31182               179.0        0.0    A1
# 31183               202.0        0.0    A1
# 31184               197.5        0.0    A1
#
# [31185 rows x 27 columns]

# %% [markdown]
# # data visualizations

# %%
data.head()
# Out:
#    Unnamed: 0  label   area  centroid-0   centroid-1  orientation  \
# 0          25     45  340.0   27.541176  7519.105882     0.202087
# 1          27     47  655.0   31.523664  8071.366412     0.619441
# 2          28     48  561.0   30.932264  1050.964349     0.645813
# 3          29     49  734.0   29.674387  9246.904632    -1.517063
# 4          30     50  462.0   32.110390  1110.318182     0.355973
#
#    major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# 0          27.802093          15.617922      14    7512  ...
# 1          38.914217          21.480542      15    8058  ...
# 2          33.850641          21.468238      16    1038  ...
# 3          32.804421          28.602714      16    9232  ...
# 4          32.500817          18.101059      17    1101  ...
#
#    01_EdU_nuc_median  nuc_mask  00_DNA_ring_median  00_EMI1_ring_median  \
# 0              169.0       0.0               125.0                419.0
# 1              322.0       0.0               132.0                425.0
# 2              181.0       0.0               144.0                449.0
# 3              171.0       0.0               138.0                421.0
# 4              191.0       0.0               132.0                428.0
#
#    00_cycB1-YFP_ring_median  00_53BP1_ring_median  01_DNA_ring_median  \
# 0                     377.0                 129.0                71.0
# 1                     357.0                 132.0               123.0
# 2                     852.0                 134.0               134.0
# 3                     505.0                 140.0               127.0
# 4                     348.0                 132.0               141.0
#
#    01_EdU_ring_median  ring_mask  well
# 0                18.0        0.0    A1
# 1               169.0        0.0    A1
# 2               168.0        0.0    A1
# 3               168.0        0.0    A1
# 4               176.0        0.0    A1
#
# [5 rows x 27 columns]

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        25
# label                             45
# area                             340
# centroid-0                   27.5412
# centroid-1                   7519.11
# orientation                 0.202087
# major_axis_length            27.8021
# minor_axis_length            15.6179
# bbox-0                            14
# bbox-1                          7512
# bbox-2                            41
# bbox-3                          7528
# 00_DNA_nuc_median               1956
# 00_EMI1_nuc_median               841
# 00_cycB1-YFP_nuc_median          409
# 00_53BP1_nuc_median              249
# 01_DNA_nuc_median              128.5
# 01_EdU_nuc_median                169
# nuc_mask                           0
# 00_DNA_ring_median               125
# 00_EMI1_ring_median              419
# 00_cycB1-YFP_ring_median         377
# 00_53BP1_ring_median             129
# 01_DNA_ring_median                71
# 01_EdU_ring_median                18
# ring_mask                          0
# well                              A1
# Name: 0, dtype: object

# %% [markdown]
# ## data clean

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        25
# label                             45
# area                             340
# centroid-0                   27.5412
# centroid-1                   7519.11
# orientation                 0.202087
# major_axis_length            27.8021
# minor_axis_length            15.6179
# bbox-0                            14
# bbox-1                          7512
# bbox-2                            41
# bbox-3                          7528
# 00_DNA_nuc_median               1956
# 00_EMI1_nuc_median               841
# 00_cycB1-YFP_nuc_median          409
# 00_53BP1_nuc_median              249
# 01_DNA_nuc_median              128.5
# 01_EdU_nuc_median                169
# nuc_mask                           0
# 00_DNA_ring_median               125
# 00_EMI1_ring_median              419
# 00_cycB1-YFP_ring_median         377
# 00_53BP1_ring_median             129
# 01_DNA_ring_median                71
# 01_EdU_ring_median                18
# ring_mask                          0
# well                              A1
# Name: 0, dtype: object

# %%
data['ABcategory'] = 'no'

# %%
data['DNA_content']=data['01_DNA_nuc_median']*data['area']

# %%
# %matplotlib notebook
data["temp"]=data["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
data1['DNA_content']=data1['01_DNA_nuc_median']*data1['area']

# %%
data2['DNA_content']=data2['01_DNA_nuc_median']*data2['area']

# %%
# %matplotlib notebook
data1["temp"]=data1["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data1)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
# %matplotlib notebook
data["temp"]=data["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data,size=0.0001)
#plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('CYCB')
plt.title('corelation of cycB with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of cycB with DNA content')

# %%
from matplotlib import colors 
from matplotlib.ticker import PercentFormatter 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 500,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('Replicate_1', fontweight ="bold") 
plt.xlim(0, 3000000)

plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 600,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('Replicate_1', fontweight ="bold") 
plt.xlim(0, 3000000)
plt.ylim(200, 600)
plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in UNTREATED group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in palbo group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in untreated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo treated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data2['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo+ emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# selct only G1 cells 
datasel=data.loc[((data['01_EdU_nuc_median']<200)&(data['DNA_content']<1400000)&(data['DNA_content']>10000)),:]
datasela=data1.loc[((data1['01_EdU_nuc_median']<200)&(data1['DNA_content']<1400000)&(data1['DNA_content']>10000)),:]
dataselb=data2.loc[((data2['01_EdU_nuc_median']<200)&(data2['DNA_content']<1400000)&(data2['DNA_content']>10000)),:]

# %%
# selct G2 cells 
dataG2=data.loc[((data['01_EdU_nuc_median']<200)&(data['DNA_content']>1400000)&(data['DNA_content']<3000000)),:]
data1G2=data1.loc[((data1['01_EdU_nuc_median']<200)&(data1['DNA_content']>1400000)&(data1['DNA_content']<3000000)),:]
data2G2=data2.loc[((data2['01_EdU_nuc_median']<200)&(data2['DNA_content']>1400000)&(data2['DNA_content']<3000000)),:]

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo+emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in EMI1+palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,hue='ABcategory')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in untreated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in untreated G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=dataselb["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=dataselb)

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells')

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and cyto_Cyclin B in untreated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in untreated G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='area',y='temp'
               ,data=dataselb,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells')

# %% [markdown]
# # Category or threshold_1 (cycb intensity>=396, 10% higher then threshold 2)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>396)|(datasel['00_cycB1-YFP_ring_median'] > 396)),'Bcategory'] = 'B_positive'

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>396)|(datasela['00_cycB1-YFP_ring_median']>396)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>396)|(dataselb['00_cycB1-YFP_ring_median']>396)),'Bcategory'] = 'B_positive'

# %% [markdown]
# # Untreated

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 17534

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 2175

# %% [markdown]
# # palbo

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 19803

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 510

# %% [markdown]
# # emi1 palbo

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 8692

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 3453

# %%
data=[[2175/17534*100],[510/19803*100],[3453/8692*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive_nuc']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df
# Out:
#             B_positive_nuc
# untreated        12.404471
# Palbo             2.575367
# palbo+emi1       39.726185

# %%
# %matplotlib notebook
ax = df[['B_positive_nuc']].plot(kind='bar', title ="Percentage with threshold_1",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_2 (cycb>360)

# %%
'

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>360)|(datasel['00_cycB1-YFP_ring_median'] > 360)),'Bcategory'] = 'B_positive'
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>360)|(datasela['00_cycB1-YFP_ring_median'] > 360)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>360)|(dataselb['00_cycB1-YFP_ring_median'] > 360)),'Bcategory'] = 'B_positive'

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 17534

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 4278

# %%
#count cells palbo treated G1 group
datasela['Bcategory'].count()
# Out:
# 19803

# %%
#count cells with cyclin B positive in in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 1827

# %%
#count cells G1 in emi1 & palbo treated cells group
dataselb['Bcategory'].count()
# Out:
# 8692

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 5753

# %%
data=[[4278/17534*100],[1827/19803*100],[5753/8692*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df_1=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df_1
# Out:
#             B_positive
# untreated    24.398312
# Palbo         9.225875
# palbo+emi1   66.187299

# %%
# %matplotlib notebook
ax = df_1[['B_positive']].plot(kind='bar', title ="Percentage with threshold_2",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_3 (cycb>324, 10% lower than the threshold 2)

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>320)|(datasel['00_cycB1-YFP_ring_median'] > 320)),'Bcategory'] = 'B_positive'
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>324)&(datasela['00_cycB1-YFP_ring_median'] > 324)),'Bcategory'] = 'B_positive'

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>324)&(dataselb['00_cycB1-YFP_ring_median'] > 324)),'Bcategory'] = 'B_positive'

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 17534

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 13787

# %%
#count cells palbo treated G1 group
datasela['Bcategory'].count()
# Out:
# 19803

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in palbo treated G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 6311

# %%
#count cells emi1 +Palbo G1 group
dataselb['Bcategory'].count()
# Out:
# 8692

# %%
#count cells with cyclin B positive in in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 7922

# %%
data=[[13787/17534*100],[6311/19803*100],[7922/8692*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df_3=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df_3
# Out:
#             B_positive
# untreated    78.630090
# Palbo        31.868909
# palbo+emi1   91.141279

# %%
# %matplotlib notebook
ax = df_3[['B_positive']].plot(kind='bar', title ="Percentage with threshold_3",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">
