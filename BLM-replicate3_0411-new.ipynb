# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
import statistics

# %%
bigDir=r'X:\Liu\for_brandon\EMI1_NEW\REP_3'

# %%
file=f'{bigDir}\\cell_data_B1_df.csv'
file1=f'{bigDir}\\cell_data_B3_df.csv'
file2=f'{bigDir}\\cell_data_B5_df.csv'

# %%
data=pd.read_csv(file)
data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data
# Out:
#        Unnamed: 0  label   area    centroid-0    centroid-1  orientation  \
# 0              33     95  436.0     25.243119   1973.048165    -0.292374
# 1              35     97  509.0     26.404715   1911.870334    -0.168366
# 2              36     98  492.0     22.815041  10038.172764    -1.011978
# 3              38    100  543.0     23.635359   7765.458564    -1.272412
# 4              39    101  418.0     25.995215   9890.880383     0.319575
# ...           ...    ...    ...           ...           ...          ...
# 34735       34816  34901  111.0  11821.108108   5953.252252     1.561652
# 34736       34817  34902   71.0  11822.633803   4123.126761     1.452485
# 34737       34818  34903   47.0  11821.765957   4468.723404    -1.489584
# 34738       34819  34904   74.0  11823.864865    995.000000     1.570796
# 34739       34820  34905   94.0  11822.957447   2911.500000     1.570796
#
#        major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# 0              31.884814          17.612278      10    1963  ...
# 1              32.485793          19.984661      11    1902  ...
# 2              32.775458          19.147600      11   10024  ...
# 3              33.291374          20.923192      12    7749  ...
# 4              29.140093          18.322049      12    9881  ...
# ...                  ...                ...     ...     ...  ...
# 34735          25.187682           5.983225   11818    5941  ...
# 34736          13.979187           6.699542   11819    4117  ...
# 34737           9.558499           6.376696   11819    4464  ...
# 34738          11.370897           8.378204   11820     990  ...
# 34739          19.955269           6.335712   11820    2902  ...
#
#        01_EdU_nuc_median  nuc_mask  00_DNA_ring_median  00_EMI1_ring_median  \
# 0                  161.0       0.0               132.0                427.0
# 1                  160.0       0.0               135.0                434.0
# 2                  168.0       0.0               138.0                448.0
# 3                  160.0       0.0               142.5                448.0
# 4                  161.0       0.0               135.0                437.0
# ...                  ...       ...                 ...                  ...
# 34735              177.0       0.0               124.0                411.0
# 34736              163.0       0.0               125.0                411.0
# 34737              184.0       0.0               127.0                415.0
# 34738              171.0       0.0               132.0                411.0
# 34739             1135.0       0.0               119.0                392.5
#
#        00_cycB1-YFP_ring_median  00_53BP1_ring_median  01_DNA_ring_median  \
# 0                         380.0                 164.0                 0.0
# 1                         412.0                 160.0               131.0
# 2                         411.0                 138.0               129.0
# 3                         570.0                 135.0               129.0
# 4                         382.0                 138.0               133.0
# ...                         ...                   ...                 ...
# 34735                     327.0                 136.0               163.5
# 34736                     327.0                 138.0               167.5
# 34737                     322.0                 139.0               157.0
# 34738                     348.0                 145.0               159.0
# 34739                     320.0                 135.0               155.0
#
#        01_EdU_ring_median  ring_mask  well
# 0                     0.0        0.0    B1
# 1                   154.0        0.0    B1
# 2                   156.0        0.0    B1
# 3                   156.0        0.0    B1
# 4                   155.0        0.0    B1
# ...                   ...        ...   ...
# 34735               162.0        0.0    B1
# 34736               161.0        0.0    B1
# 34737               180.0        0.0    B1
# 34738               171.0        0.0    B1
# 34739               188.5        0.0    B1
#
# [34740 rows x 27 columns]

# %% [markdown]
# # data visualizations

# %%
data.head()
# Out:
#    Unnamed: 0  label   area  centroid-0    centroid-1  orientation  \
# 0          33     95  436.0   25.243119   1973.048165    -0.292374
# 1          35     97  509.0   26.404715   1911.870334    -0.168366
# 2          36     98  492.0   22.815041  10038.172764    -1.011978
# 3          38    100  543.0   23.635359   7765.458564    -1.272412
# 4          39    101  418.0   25.995215   9890.880383     0.319575
#
#    major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# 0          31.884814          17.612278      10    1963  ...
# 1          32.485793          19.984661      11    1902  ...
# 2          32.775458          19.147600      11   10024  ...
# 3          33.291374          20.923192      12    7749  ...
# 4          29.140093          18.322049      12    9881  ...
#
#    01_EdU_nuc_median  nuc_mask  00_DNA_ring_median  00_EMI1_ring_median  \
# 0              161.0       0.0               132.0                427.0
# 1              160.0       0.0               135.0                434.0
# 2              168.0       0.0               138.0                448.0
# 3              160.0       0.0               142.5                448.0
# 4              161.0       0.0               135.0                437.0
#
#    00_cycB1-YFP_ring_median  00_53BP1_ring_median  01_DNA_ring_median  \
# 0                     380.0                 164.0                 0.0
# 1                     412.0                 160.0               131.0
# 2                     411.0                 138.0               129.0
# 3                     570.0                 135.0               129.0
# 4                     382.0                 138.0               133.0
#
#    01_EdU_ring_median  ring_mask  well
# 0                 0.0        0.0    B1
# 1               154.0        0.0    B1
# 2               156.0        0.0    B1
# 3               156.0        0.0    B1
# 4               155.0        0.0    B1
#
# [5 rows x 27 columns]

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        33
# label                             95
# area                             436
# centroid-0                   25.2431
# centroid-1                   1973.05
# orientation                -0.292374
# major_axis_length            31.8848
# minor_axis_length            17.6123
# bbox-0                            10
# bbox-1                          1963
# bbox-2                            40
# bbox-3                          1983
# 00_DNA_nuc_median             1623.5
# 00_EMI1_nuc_median               693
# 00_cycB1-YFP_nuc_median          385
# 00_53BP1_nuc_median            277.5
# 01_DNA_nuc_median                378
# 01_EdU_nuc_median                161
# nuc_mask                           0
# 00_DNA_ring_median               132
# 00_EMI1_ring_median              427
# 00_cycB1-YFP_ring_median         380
# 00_53BP1_ring_median             164
# 01_DNA_ring_median                 0
# 01_EdU_ring_median                 0
# ring_mask                          0
# well                              B1
# Name: 0, dtype: object

# %% [markdown]
# ## data clean

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        33
# label                             95
# area                             436
# centroid-0                   25.2431
# centroid-1                   1973.05
# orientation                -0.292374
# major_axis_length            31.8848
# minor_axis_length            17.6123
# bbox-0                            10
# bbox-1                          1963
# bbox-2                            40
# bbox-3                          1983
# 00_DNA_nuc_median             1623.5
# 00_EMI1_nuc_median               693
# 00_cycB1-YFP_nuc_median          385
# 00_53BP1_nuc_median            277.5
# 01_DNA_nuc_median                378
# 01_EdU_nuc_median                161
# nuc_mask                           0
# 00_DNA_ring_median               132
# 00_EMI1_ring_median              427
# 00_cycB1-YFP_ring_median         380
# 00_53BP1_ring_median             164
# 01_DNA_ring_median                 0
# 01_EdU_ring_median                 0
# ring_mask                          0
# well                              B1
# Name: 0, dtype: object

# %%
data['ABcategory'] = 'no'

# %%
data['DNA_content']=data['01_DNA_nuc_median']*data['area']

# %%
# %matplotlib notebook
data["temp"]=data["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
data1['DNA_content']=data1['01_DNA_nuc_median']*data1['area']

# %%
data2['DNA_content']=data2['01_DNA_nuc_median']*data2['area']

# %%
# %matplotlib notebook
data1["temp"]=data1["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data1)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
# %matplotlib notebook
data["temp"]=data["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data,size=0.0001)
#plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('CYCB')
plt.title('corelation of cycB with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of cycB with DNA content')

# %%
from matplotlib import colors 
from matplotlib.ticker import PercentFormatter 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 500,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_3', fontweight ="bold") 
plt.xlim(0, 3000000)

plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 500,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_3', fontweight ="bold") 
plt.xlim(0, 3000000)
plt.ylim(0, 1500)
plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 600,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_3', fontweight ="bold") 
plt.xlim(0, 3000000)
plt.ylim(200, 600)
plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in UNTREATED group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in palbo group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in untreated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo treated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data2['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo+ emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# selct only G1 cells 
datasel=data.loc[((data['01_EdU_nuc_median']<200)&(data['DNA_content']<1100000)&(data['DNA_content']>10000)),:]
datasela=data1.loc[((data1['01_EdU_nuc_median']<200)&(data1['DNA_content']<1100000)&(data1['DNA_content']>10000)),:]
dataselb=data2.loc[((data2['01_EdU_nuc_median']<200)&(data2['DNA_content']<1100000)&(data2['DNA_content']>10000)),:]

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo+emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in EMI1+palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,hue='ABcategory')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=dataselb["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=dataselb)

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells')

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in cyto')
plt.title('corelation of nuclear size and cyto_Cyclin B in untreated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in untreated G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='DNA_content',y='temp'
               ,data=dataselb,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells')

# %% [markdown]
# # Category or threshold_1(cycb>423,10% higher then threshold 2)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>423)|(datasel['00_cycB1-YFP_ring_median'] >423)),'Bcategory'] = 'B_positive'
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>423)|(datasela['00_cycB1-YFP_ring_median'] >423)),'Bcategory'] = 'B_positive'

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>423)|(dataselb['00_cycB1-YFP_ring_median'] >423)),'Bcategory'] = 'B_positive'

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 18426

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 1948

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 20867

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 712

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 7325

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 1752

# %%
data=[[1948/18426*100],[712/20867*100],[1752/7325*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="threshold_1",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_2 (cycb>385)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>385)|(datasel['00_cycB1-YFP_ring_median'] >385)),'Bcategory'] = 'B_positive'

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>385)|(datasela['00_cycB1-YFP_ring_median'] >385)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>385)|(dataselb['00_cycB1-YFP_ring_median'] >385)),'Bcategory'] = 'B_positive'

# %% [markdown]
# # UNTREATED

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 18426

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 4461

# %% [markdown]
# # Palbo

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 20867

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 2458

# %% [markdown]
# # emi1+palbo

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 7325

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 3476

# %%
data=[[4461/18426*100],[2458/20867*100],[3476/7325*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df
# Out:
#             B_positive
# untreated    24.210355
# Palbo        11.779365
# palbo+emi1   47.453925

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="threshold_2",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_3 (cycb intensity<=302)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>347)&(datasel['00_cycB1-YFP_ring_median'] >347)),'Bcategory'] = 'B_positive'

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>347)&(datasela['00_cycB1-YFP_ring_median'] >347)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>347)&(dataselb['00_cycB1-YFP_ring_median'] >347)),'Bcategory'] = 'B_positive'

# %% [markdown]
# # Untreated

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 18426

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 9551

# %% [markdown]
# # palbo

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 20867

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 6768

# %% [markdown]
# # emi1 palbo

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 7325

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 5135

# %%
data=[[9551/18426*100],[6768/20867*100],[5135/7325*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df
# Out:
#             B_positive
# untreated    51.834364
# Palbo        32.433987
# palbo+emi1   70.102389

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="Percentage with threshold_3",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">
