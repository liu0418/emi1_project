# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
import statistics

# %%
bigDir=r'X:\Liu\for_brandon\EMI1_NEW\REP_2'

# %%
file=f'{bigDir}\\cell_data_A1_df.csv'
file1=f'{bigDir}\\cell_data_A3_df.csv'
file2=f'{bigDir}\\cell_data_A5_df.csv'

# %%
data=pd.read_csv(file)
data1=pd.read_csv(file1)
data2=pd.read_csv(file2)

# %%
data
# Out:
#        Unnamed: 0  label    area    centroid-0   centroid-1  orientation  \
# 0              17     90  1169.0     30.968349  1397.401198    -0.320312
# 1              18     91   554.0     24.339350  1433.371841    -0.614072
# 2              19     92   583.0     24.226415  3002.785592     0.711842
# 3              21     94   626.0     25.341853  7894.230032    -0.982368
# 4              22     95   525.0     25.904762  9060.483810    -0.742536
# ...           ...    ...     ...           ...          ...          ...
# 36193       36251  36333    71.0  11829.943662  4384.126761    -1.519721
# 36194       36252  36334   108.0  11831.555556   259.250000     1.542263
# 36195       36253  36335    45.0  11830.311111  4681.444444     1.550568
# 36196       36254  36336    71.0  11831.957746  2318.436620    -1.512369
# 36197       36255  36337    43.0  11831.255814  3658.325581    -1.497229
#
#        major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# ...

# %% [markdown]
# # data visualizations

# %%
data.head()
# Out:
#    Unnamed: 0  label    area  centroid-0   centroid-1  orientation  \
# 0          17     90  1169.0   30.968349  1397.401198    -0.320312
# 1          18     91   554.0   24.339350  1433.371841    -0.614072
# 2          19     92   583.0   24.226415  3002.785592     0.711842
# 3          21     94   626.0   25.341853  7894.230032    -0.982368
# 4          22     95   525.0   25.904762  9060.483810    -0.742536
#
#    major_axis_length  minor_axis_length  bbox-0  bbox-1  ...  \
# 0          43.466764          34.292025      10    1380  ...
# 1          34.653019          20.390983      10    1421  ...
# 2          33.056199          22.518364      10    2990  ...
# 3          36.734702          21.726705      12    7878  ...
# 4          34.333678          19.783921      12    9047  ...
#
#    01_EdU_nuc_median  nuc_mask  00_DNA_ring_median  00_EMI1_ring_median  \
# 0              173.0       0.0               146.0                468.0
# ...

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        17
# label                             90
# area                            1169
# centroid-0                   30.9683
# centroid-1                    1397.4
# orientation                -0.320312
# major_axis_length            43.4668
# minor_axis_length             34.292
# bbox-0                            10
# bbox-1                          1380
# bbox-2                            53
# bbox-3                          1415
# 00_DNA_nuc_median                725
# 00_EMI1_nuc_median               624
# 00_cycB1-YFP_nuc_median          299
# 00_53BP1_nuc_median              372
# 01_DNA_nuc_median                714
# 01_EdU_nuc_median                173
# nuc_mask                           0
# 00_DNA_ring_median               146
# 00_EMI1_ring_median              468
# 00_cycB1-YFP_ring_median         297
# 00_53BP1_ring_median             140
# 01_DNA_ring_median               135
# 01_EdU_ring_median               173
# ...

# %% [markdown]
# ## data clean

# %%
data.iloc[0]
# Out:
# Unnamed: 0                        17
# label                             90
# area                            1169
# centroid-0                   30.9683
# centroid-1                    1397.4
# orientation                -0.320312
# major_axis_length            43.4668
# minor_axis_length             34.292
# bbox-0                            10
# bbox-1                          1380
# bbox-2                            53
# bbox-3                          1415
# 00_DNA_nuc_median                725
# 00_EMI1_nuc_median               624
# 00_cycB1-YFP_nuc_median          299
# 00_53BP1_nuc_median              372
# 01_DNA_nuc_median                714
# 01_EdU_nuc_median                173
# nuc_mask                           0
# 00_DNA_ring_median               146
# 00_EMI1_ring_median              468
# 00_cycB1-YFP_ring_median         297
# 00_53BP1_ring_median             140
# 01_DNA_ring_median               135
# 01_EdU_ring_median               173
# ...

# %%
data['ABcategory'] = 'no'

# %%
data['DNA_content']=data['01_DNA_nuc_median']*data['area']

# %%
# %matplotlib notebook
data["temp"]=data["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
data1['DNA_content']=data1['01_DNA_nuc_median']*data1['area']

# %%
data2['DNA_content']=data2['01_DNA_nuc_median']*data2['area']

# %%
# %matplotlib notebook
data1["temp"]=data1["01_EdU_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data1)
plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('EdU encorporation')
plt.title('corelation of EdU with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of EdU with DNA content')

# %%
# %matplotlib notebook
data["temp"]=data["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='DNA_content',y='temp' ,data=data,size=0.0001)
#plt.yscale('log')
plt.legend()
plt.xlabel('DNA content')
plt.ylabel('CYCB')
plt.title('corelation of cycB with DNA content', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of cycB with DNA content')

# %%
from matplotlib import colors 
from matplotlib.ticker import PercentFormatter 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 500,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_2', fontweight ="bold") 
plt.xlim(0, 3000000)

plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 500,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_2', fontweight ="bold") 
plt.xlim(0, 3000000)
plt.ylim(0, 1500)
plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
x = data.DNA_content

y = data["00_cycB1-YFP_nuc_median"]
plt.hist2d(x, y, 
           bins = 600,    norm = colors.LogNorm(), 
          
           cmap ="viridis") 
  
plt.title('replicate_2', fontweight ="bold") 
plt.xlim(0, 3000000)
plt.ylim(200, 600)
plt.xlabel('DNA content')
plt.ylabel('CYCB')

  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in UNTREATED group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['DNA_content'], color='purple', ec='black', bins=100)
plt.xlabel("DNA content")
plt.ylabel("Frequency")
plt.title("Distribution of DNA in palbo group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in untreated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data1['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo treated group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(data2['01_EdU_nuc_median'], color='lightgreen', ec='black', bins=100)
plt.xlabel("EdU intensity")
plt.ylabel("Frequency")
plt.title("Distribution of edu in palbo+ emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# selct only G1 cells 
datasel=data.loc[((data['01_EdU_nuc_median']<200)&(data['DNA_content']<1000000)&(data['DNA_content']>10000)),:]
datasela=data1.loc[((data1['01_EdU_nuc_median']<200)&(data1['DNA_content']<1000000)&(data1['DNA_content']>10000)),:]
dataselb=data2.loc[((data2['01_EdU_nuc_median']<200)&(data2['DNA_content']<1000000)&(data2['DNA_content']>10000)),:]

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_nuc_median'], color='blue', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of nuc_cyclinB in palbo+emi1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasel['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in untreated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(datasela['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Create a histogram
# %matplotlib notebook
plt.hist(dataselb['00_cycB1-YFP_ring_median'], color='yellow', ec='black', bins=100)
plt.xlabel("CYCB intensity")
plt.ylabel("Frequency")
plt.title("Distribution of cyt_cyclinB in EMI1+palbo treated G1 group")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,hue='ABcategory')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=dataselb["00_cycB1-YFP_nuc_median"]
sn.scatterplot(x='area',y='temp'
               ,data=dataselb)

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and Cyclin B in emi1+palbo treated G1 cells')

# %%
# %matplotlib notebook
datasel["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='area',y='temp'
               ,data=datasel,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in cyto')
plt.title('corelation of nuclear size and cyto_Cyclin B in untreated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in untreated G1 cells')

# %%
# %matplotlib notebook
dataselb["temp"]=datasel["00_cycB1-YFP_ring_median"]
sn.scatterplot(x='DNA_content',y='temp'
               ,data=dataselb,color='yellow')

plt.legend()
plt.xlabel('nuclear size')
plt.ylabel(' CYCB in Nucleus')
plt.title('corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells', fontsize=10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <img src="data:image/png;base64,..." width="639.999974568686">
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'corelation of nuclear size and cyto_Cyclin B in emi1+palbo treated G1 cells')

# %% [markdown]
# # Category or threshold_1(cycb>368,10% higher then threshold 2)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>368)|(datasel['00_cycB1-YFP_ring_median'] >368)),'Bcategory'] = 'B_positive'

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>368)|(datasela['00_cycB1-YFP_ring_median'] >368)),'Bcategory'] = 'B_positive'

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>368)|(dataselb['00_cycB1-YFP_ring_median'] >368)),'Bcategory'] = 'B_positive'

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 19625

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 2689

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 23102

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 699

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 9588

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 3436

# %%
data=[[2689/19625*100],[699/23102*100],[3436/9588*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="threshold_1",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_2 (cycb>335)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>335)|(datasel['00_cycB1-YFP_ring_median'] > 335)),'Bcategory'] = 'B_positive'
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>335)|(datasela['00_cycB1-YFP_ring_median'] >335)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>335)|(dataselb['00_cycB1-YFP_ring_median'] >335)),'Bcategory'] = 'B_positive'

# %% [markdown]
# # UNTREATED

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 19625

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 5233

# %% [markdown]
# # Palbo

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 23102

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 2526

# %% [markdown]
# # emi1+palbo

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 9588

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 6056

# %%
data=[[5233/19625*100],[2526/23102*100],[6056/9588*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df
# Out:
#             B_positive
# untreated    26.664968
# Palbo        10.934118
# palbo+emi1   63.162286

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="threshold_2",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# # Category or threshold_3 (cycb intensity<=302)

# %%
datasel['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasel.loc[((datasel['00_cycB1-YFP_nuc_median']>302)&(datasel['00_cycB1-YFP_ring_median'] >302)),'Bcategory'] = 'B_positive'

# %%
datasela['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datasela.loc[((datasela['00_cycB1-YFP_nuc_median']>302)&(datasela['00_cycB1-YFP_ring_median'] >302)),'Bcategory'] = 'B_positive'

# %%
dataselb['Bcategory'] = 'no'
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataselb.loc[((dataselb['00_cycB1-YFP_nuc_median']>302)&(dataselb['00_cycB1-YFP_ring_median'] >302)),'Bcategory'] = 'B_positive'

# %% [markdown]
# # Untreated

# %%
#count cells Untreated G1 group
datasel['Bcategory'].count()
# Out:
# 19625

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in untreated G1 group
datasel.loc[datasel['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 11874

# %% [markdown]
# # palbo

# %%
#count cells G1 group
datasela['Bcategory'].count()
# Out:
# 23102

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in Palbo G1 group
datasela.loc[datasela['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 8647

# %% [markdown]
# # emi1 palbo

# %%
#count cells G1 group
dataselb['Bcategory'].count()
# Out:
# 9588

# %%
#count cells with cyclin B positive in nuclear&cytoplasm in emi1 +Palbo G1 group
dataselb.loc[dataselb['Bcategory'] == 'B_positive', 'Bcategory'].count()
# Out:
# 8769

# %%
data=[[11874/19625*100],[8647/23102*100],[8769/9588*100]]
group=['untreated','Palbo','palbo+emi1']
columns=['B_positive']
df=pd.DataFrame(data=data, index=group, columns=columns)

# %%
df
# Out:
#             B_positive
# untreated    60.504459
# Palbo        37.429660
# palbo+emi1   91.458073

# %%
# %matplotlib notebook
ax = df[['B_positive']].plot(kind='bar', title ="Percentage with threshold_3",figsize=(5,5),legend=True, fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">
